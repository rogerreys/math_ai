# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
    return np.sin(x)
def df(x):
    h=0.000001
    return (f(x+h)-f(x))/h

x = np.linspace(-10,10, 1000)
y = f(x)
dy = df(x)

plt.plot(x,y)
plt.plot(x,dy)
plt.grid()
