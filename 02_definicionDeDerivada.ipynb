# %% [markdown]
# # Derivada
# Se puede tener mas detalle al video <a src="https://www.youtube.com/watch?v=6kyG3pxeSM8">Ver</a>
#
# ## Ecuacion
# |||
# |---|---|
# |<img src="src/img/recta_tangente.png" width="500px">|$$f(x) = mx +b$$ <br> $$tan(\alpha) = m = \frac{\delta_y}{\delta_x} = \frac{y_2 - y_1}{x_2-x_1} = \frac{f(x+h) - f(x)}{x+h-x}$$ <br> $$tan(\alpha) = m = \frac{f(x+h) - f(x)}{h}$$ <br> Usando el limite cuando $h→0$ (h tienda a cero) <br> $$ \frac{dy}{dx} = \frac{d}{dx}f(x) = \lim_{h \to 0}\frac{f(x+h) - f(x)}{h}$$|
#
# ## Ejemplo

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return x**2

def df(x):
    return 2*x

x = np.linspace(-10, 10, 100)
y = f(x)
dy = df(x)

plt.plot(x,y)
plt.plot(x,dy)
plt.plot([-10,10],[0,0], color="red")
plt.plot([0,0],[-20,100], color="red")

# %% [markdown]
# ## Explicacion de grafica
# La grafica de la derivada indica que:
# De -10 a 0 sus valores son decrecientes
# De 0 a 10 sus valores son crecientes
#
# ## Derivadas
# <img src="https://static.platzi.com/media/public/uploads/derivadas_9e208991-949b-4c24-bedf-cb94464320a3.gif">
